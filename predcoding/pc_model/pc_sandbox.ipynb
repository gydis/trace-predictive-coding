# %%
# %load_ext autoreload
# %autoreload 2
from pc_training import TracePCTrainConfig, PCInferenceConfig, train_trace_model, evaluate_trace_model
import seaborn as sns
import matplotlib.pyplot as plt
from dataloader import TraceDataset
import numpy as np
from torch.utils.data import DataLoader
import torch
from torch.nn import functional as F

# %%
inference = PCInferenceConfig(
    n_steps=20,
    step_size=0.1,
    until_converged=False,
    convergence_tol=1e-5,
    max_steps=1000,
    min_steps=1,
    energy_reduction='mean',
    # state_optimizer="adam",
    # state_optimizer_kwargs={"lr": 1e-2},
)
config = TracePCTrainConfig(
    test_split=0,
    epochs=100,
    noise=0,
    steps_per_phoneme=None,
    inference=inference,
    clamp_output_at_last_step=True,
    early_stop_on_train_acc=False,
    learning_rate=1e-3,
    train_weight_every_phoneme=True,
    learn_precision=True,
    precision_init=1,
    mean_approx=False,
    hidden_nonlinearity=torch.nn.ReLU(),
    output_nonlinearity=None,
    include_output_layer=True,
    weight_norm=None,
    init_scale=0.1,
    label_force_every_phoneme=True,
    use_supervised_energy_only=False
)
result = train_trace_model(config=config)
model = result.model
history = result.history
train_dataloader = result.train_dataloader
val_dataloader = result.val_dataloader

free_energy = history["free_energy"]
gradients = history["grad_norm"]
accuracies = history["acc"]
val_accuracies = history["val_acc"]
precisions = np.array(history["precision"])
weight_norm_pre_inf = np.array(history["weight_norm_pre_inf"])
weight_norm_post_inf = np.array(history["weight_norm_post_inf"])
# Out:
# Epoch 43/100 F: 2.9435 Acc: 0.00, Val 0.00%:  43%|████▎     | 43/100 [00:25<00:31,  1.83it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 38
#       1 inference = PCInferenceConfig(
#       2     n_steps=20,
#       3     step_size=0.1,
#    (...)     10     # state_optimizer_kwargs={"lr": 1e-2},
#      11 )
#      12 config = TracePCTrainConfig(
#      13     test_split=0,
#      14     epochs=100,
#    (...)     36     label_energy_in_inference=True,
#      37 )
# ---> 38 result = train_trace_model(config=config)
#      39 model = result.model
#      40 history = result.history
#
# File ~/Documents/Projects/Msc thesis/trace_python/predcoding/pc_training.py:251, in train_trace_model(config, model, dataloaders, dataset)
#     247 model.layers[0].clamp(features[:, step_idx, :])
#     248 history["weight_norm_pre_inf"].append(
#     249     sum(p.norm().item() for p in model.weight_parameters())
#     250 )
# --> 251 model.infer(
#     252     config=config.inference,
#     253     n_steps=steps_per_phoneme,
#     254     target=infer_target,
#     255     label_weight=config.label_energy_weight if infer_target is not None else None,
#     256 )
#     257 history["weight_norm_post_inf"].append(
#     258     sum(p.norm().item() for p in model.weight_parameters())
#     259 )
#     261 if step_idx == seq_len - 1:
#
# File ~/Documents/Projects/Msc thesis/trace_python/predcoding/pc_models.py:354, in PCModel.infer(self, config, n_steps, step_size, energy_reduction, target, label_weight)
#     347         prev_states.append(layer.state.detach().clone())
#     349 energy, _ = self.free_energy(
#     350     reduction=energy_reduction,
#     351     target=target,
#     352     label_weight=label_weight,
#     353 )
# --> 354 grads = torch.autograd.grad(energy, free_states)
#     356 with torch.no_grad():
#     357     if optimizer is None:
#
# File ~/Documents/Projects/Msc thesis/.venv/lib/python3.14/site-packages/torch/autograd/__init__.py:515, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched, materialize_grads)
#     511     result = _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(
#     512         grad_outputs_
#     513     )
#     514 else:
# --> 515     result = _engine_run_backward(
#     516         outputs,
#     517         grad_outputs_,
#     518         retain_graph,
#     519         create_graph,
#     520         inputs,
#     521         allow_unused,
#     522         accumulate_grad=False,
#     523     )
#     524 if materialize_grads:
#     525     if any(
#     526         result[i] is None and not is_tensor_like(inputs[i])
#     527         for i in range(len(inputs))
#     528     ):
#
# File ~/Documents/Projects/Msc thesis/.venv/lib/python3.14/site-packages/torch/autograd/graph.py:865, in _engine_run_backward(t_outputs, *args, **kwargs)
#     863     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     864 try:
# --> 865     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     866         t_outputs, *args, **kwargs
#     867     )  # Calls into the C++ engine to run the backward pass
#     868 finally:
#     869     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Plot the history

# %%
sns.lineplot(accuracies, label='Train Accuracy')
plt.show()
sns.lineplot(val_accuracies, label='Validation Accuracy')
plt.show()
sns.lineplot(free_energy, label='Free Energy')
plt.show()
sns.lineplot(gradients, label='Gradient Norm')
plt.show()
sns.lineplot(precisions[:, 0], label='Precision hidden')
sns.lineplot(precisions[:, 1], label='Precision output')
plt.show()
sns.lineplot(weight_norm_pre_inf, label='Weight Norm Pre Inference')
sns.lineplot(weight_norm_post_inf, label='Weight Norm Post Inference')
plt.show()

# %%
acc, predictions, original_words = evaluate_trace_model(model, train_dataloader, config)

# %%
acc
# Out:
# 0.46511627906976744

# %%
for p, w in zip(predictions, original_words):
    pred_w = TraceDataset().words_padded[p.item()]
    if pred_w[:len(w)] != w:
        print(f"Predicted: {pred_w}, Original: {w}")
# Out:
# Predicted: p^t------, Original: si
# Predicted: p^t------, Original: s^t^l
# Predicted: p^t------, Original: spark
# Predicted: p^t------, Original: badi
# Predicted: p^t------, Original: art^st
# Predicted: p^t------, Original: trup
# Predicted: p^t------, Original: slip
# Predicted: p^t------, Original: b^b^l
# Predicted: p^t------, Original: str^k
# Predicted: p^t------, Original: drap
# Predicted: p^t------, Original: pradus
# Predicted: p^t------, Original: st^di
# Predicted: p^t------, Original: tru
# Predicted: p^t------, Original: tub
# Predicted: p^t------, Original: gru
# Predicted: p^t------, Original: bl^S
# Predicted: p^t------, Original: Sild
# Predicted: p^t------, Original: pl^g
# Predicted: p^t------, Original: truli
# Predicted: p^t------, Original: park
# Predicted: p^t------, Original: Sak
# Predicted: p^t------, Original: sut
# Predicted: p^t------, Original: kar
# Predicted: p^t------, Original: d^st
# Predicted: p^t------, Original: rak
# Predicted: p^t------, Original: lak
# Predicted: p^t------, Original: targ^t
# Predicted: p^t------, Original: grit
# Predicted: p^t------, Original: S^t
# Predicted: p^t------, Original: rab
# Predicted: p^t------, Original: strit
# Predicted: p^t------, Original: pip^l
# Predicted: p^t------, Original: trit
# Predicted: p^t------, Original: parti
# Predicted: p^t------, Original: rili
# Predicted: p^t------, Original: kruS^l
# Predicted: p^t------, Original: spik
# Predicted: p^t------, Original: s^ksid
# Predicted: p^t------, Original: rut
# Predicted: p^t------, Original: dart
# Predicted: p^t------, Original: bl^d
# Predicted: p^t------, Original: pis
# Predicted: p^t------, Original: start
# Predicted: p^t------, Original: gad
# Predicted: p^t------, Original: lup
# Predicted: p^t------, Original: sik
# Predicted: p^t------, Original: ^d^lt
# Predicted: p^t------, Original: bist
# Predicted: p^t------, Original: l^k
# Predicted: p^t------, Original: ^pil
# Predicted: p^t------, Original: ist
# Predicted: p^t------, Original: plat
# Predicted: p^t------, Original: r^b
# Predicted: p^t------, Original: pas^bli
# Predicted: p^t------, Original: did
# Predicted: p^t------, Original: bark
# Predicted: p^t------, Original: ad
# Predicted: p^t------, Original: ^br^pt
# Predicted: p^t------, Original: kard
# Predicted: p^t------, Original: lig^l
# Predicted: p^t------, Original: it
# Predicted: p^t------, Original: pap^
# Predicted: p^t------, Original: d^b^l
# Predicted: p^t------, Original: kalig
# Predicted: p^t------, Original: sari
# Predicted: p^t------, Original: spat
# Predicted: p^t------, Original: strik
# Predicted: p^t------, Original: labi
# Predicted: p^t------, Original: g^tar
# Predicted: p^t------, Original: ^
# Predicted: p^t------, Original: dr^g
# Predicted: p^t------, Original: stup^d
# Predicted: p^t------, Original: karp^t
# Predicted: p^t------, Original: Sr^g
# Predicted: p^t------, Original: ^gli
# Predicted: p^t------, Original: bat^l
# Predicted: p^t------, Original: str^g^l
# Predicted: p^t------, Original: tr^k
# Predicted: p^t------, Original: pak^t
# Predicted: p^t------, Original: br^S
# Predicted: p^t------, Original: Sit
# Predicted: p^t------, Original: tar
# Predicted: p^t------, Original: ti
# Predicted: p^t------, Original: sl^g
# Predicted: p^t------, Original: skul
# Predicted: p^t------, Original: r^s^l
# Predicted: p^t------, Original: dal
# Predicted: p^t------, Original: grup
# Predicted: p^t------, Original: lig
# Predicted: p^t------, Original: lat
# Predicted: p^t------, Original: l^kS^ri
# Predicted: p^t------, Original: dat
# Predicted: p^t------, Original: pi
# Predicted: p^t------, Original: gard
# Predicted: p^t------, Original: rak^t
# Predicted: p^t------, Original: r^g^d
# Predicted: p^t------, Original: tu
# Predicted: p^t------, Original: rig^
# Predicted: p^t------, Original: kapi
# Predicted: p^t------, Original: b^s
# Predicted: p^t------, Original: rupi
# Predicted: p^t------, Original: ^dapt
# Predicted: p^t------, Original: prab^bli
# Predicted: p^t------, Original: r^S
# Predicted: p^t------, Original: art
# Predicted: p^t------, Original: pl^s
# Predicted: p^t------, Original: bi
# Predicted: p^t------, Original: su
# Predicted: p^t------, Original: stak
# Predicted: p^t------, Original: p^lis
# Predicted: p^t------, Original: ki
# Predicted: p^t------, Original: kul
# Predicted: p^t------, Original: tr^sti
# Predicted: p^t------, Original: klak
# Predicted: p^t------, Original: klu
# Predicted: p^t------, Original: tul
# Predicted: p^t------, Original: ^p
# Predicted: p^t------, Original: sid
# Predicted: p^t------, Original: star
# Predicted: p^t------, Original: dil
# Predicted: p^t------, Original: tr^b^l
# Predicted: p^t------, Original: kru
# Predicted: p^t------, Original: krap
# Predicted: p^t------, Original: lip
# Predicted: p^t------, Original: sikr^t
# Predicted: p^t------, Original: pal^si
# Predicted: p^t------, Original: ril
# Predicted: p^t------, Original: kap
# Predicted: p^t------, Original: kip
# Predicted: p^t------, Original: blak
# Predicted: p^t------, Original: baks
# Predicted: p^t------, Original: rid
# Predicted: p^t------, Original: ark
# Predicted: p^t------, Original: partli
# Predicted: p^t------, Original: skar
# Predicted: p^t------, Original: k^p^l
# Predicted: p^t------, Original: Sat
# Predicted: p^t------, Original: prist
# Predicted: p^t------, Original: prab^b^l
# Predicted: p^t------, Original: lus
# Predicted: p^t------, Original: kl^b
# Predicted: p^t------, Original: bust
# Predicted: p^t------, Original: gat
# Predicted: p^t------, Original: pat
# Predicted: p^t------, Original: k^p
# Predicted: p^t------, Original: tr^st
# Predicted: p^t------, Original: pas^b^l
# Predicted: p^t------, Original: spid
# Predicted: p^t------, Original: bab
# Predicted: p^t------, Original: ar
# Predicted: p^t------, Original: kr^S
# Predicted: p^t------, Original: pap
# Predicted: p^t------, Original: bar
# Predicted: p^t------, Original: slit
# Predicted: d^l------, Original: -
# Predicted: p^t------, Original: Sut
# Predicted: p^t------, Original: list
# Predicted: p^t------, Original: tap
# Predicted: p^t------, Original: grik
# Predicted: p^t------, Original: pul
# Predicted: p^t------, Original: ^lat
# Predicted: p^t------, Original: start^l
# Predicted: p^t------, Original: prad^kt
# Predicted: p^t------, Original: duti
# Predicted: p^t------, Original: brud
# Predicted: p^t------, Original: s^k
# Predicted: p^t------, Original: but
# Predicted: p^t------, Original: dru
# Predicted: p^t------, Original: stap
# Predicted: p^t------, Original: part
# Predicted: p^t------, Original: sut^b^l
# Predicted: p^t------, Original: dip
# Predicted: p^t------, Original: rad
# Predicted: p^t------, Original: b^t
# Predicted: p^t------, Original: lid
# Predicted: p^t------, Original: stip
# Predicted: p^t------, Original: ^part
# Predicted: p^t------, Original: ^s
# Predicted: p^t------, Original: s^bst^tut
# Predicted: p^t------, Original: kru^l
# Predicted: p^t------, Original: glu
# Predicted: p^t------, Original: Sap
# Predicted: p^t------, Original: l^ki
# Predicted: p^t------, Original: ^slip
# Predicted: p^t------, Original: trat
# Predicted: p^t------, Original: sit
# Predicted: p^t------, Original: dark
# Predicted: p^t------, Original: par
# Predicted: p^t------, Original: b^k
# Predicted: p^t------, Original: pragr^s
# Predicted: p^t------, Original: babi
# Predicted: p^t------, Original: parS^l
# Predicted: p^t------, Original: triti
# Predicted: p^t------, Original: st^did
# Predicted: p^t------, Original: d^k
# Predicted: p^t------, Original: k^t
# Predicted: p^t------, Original: stil
# Predicted: p^t------, Original: sis
# Predicted: p^t------, Original: skru
# Predicted: p^t------, Original: brid
# Predicted: p^t------, Original: sal^d
# Predicted: p^t------, Original: pik
# Predicted: p^t------, Original: Sarp
# Predicted: p^t------, Original: blu
# Predicted: p^t------, Original: d^l
# Predicted: p^t------, Original: bit
# Predicted: p^t------, Original: rul
# Predicted: p^t------, Original: Si
# Predicted: p^t------, Original: du
# Predicted: p^t------, Original: krip
# Predicted: p^t------, Original: Sip
# Predicted: p^t------, Original: sil
# Predicted: p^t------, Original: tri
# Predicted: p^t------, Original: ^gri

# %% [markdown]
# ## Simple inference visualization

# %%
def pc_viz(model, input_vec, n_steps=50, step_size=0.05):
    model.eval()
    model.reset()
    model.release_clamp()

    if input_vec.ndim == 1:
        input_vec = input_vec.unsqueeze(0)
    model.layers[0].clamp(input_vec)

    layer_names = list(model.layers._modules.keys())
    errors = {name: [] for name in layer_names[1:]}

    for _ in range(n_steps):
        model.infer(n_steps=1, step_size=step_size)
        for idx in range(1, len(model.layers)):
            upper = model.layers[idx]
            lower = model.layers[idx - 1]
            prediction = upper.predict_down()
            error = (lower.state - prediction).detach()
            err_norm = error.norm(dim=tuple(range(1, error.ndim))).mean().item()
            errors[layer_names[idx]].append(err_norm)

    for name, vals in errors.items():
        plt.plot(vals, label=name)
    plt.xlabel('Inference step')
    plt.ylabel('Prediction error norm')
    plt.legend()
    plt.show()

device = model.device
words, features, labels_ind = next(iter(train_dataloader)).values()
features = features.to(device)

pc_viz(model, features[0, 0], n_steps=50, step_size=0.05)
