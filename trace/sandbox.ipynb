# %%
# %load_ext autoreload
# %autoreload 2
from learning import trace
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from utils import *
from settings import *
from plots import plot_phoneme_responses, plot_feature_responses, plot_word_unit_responses, plot_probe_responses
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
input_string = "art--"  # Input string
slice_num = 11 + 7 * (len(input_string)-1) # Number of time slices

input_indices = get_input_indices(slice_num, input_string)

# %%
probes = [("l^k", 4), ("l^kS^ri", 5), ("l^kS^ri", 6)]
# %prun feature_values_agg, phoneme_values_agg, word_values_agg, probe_values = trace(input_string, probes)
# Out:
#          380220 function calls (379528 primitive calls) in 8.400 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       786    6.524    0.008    6.566    0.008 {built-in method time.sleep}
#       428    0.414    0.001    0.430    0.001 {method 'poll' of 'select.poll' objects}
#       117    0.335    0.003    0.618    0.005 cloudpickle.py:338(_find_imported_submodules)
#    184119    0.290    0.000    0.290    0.000 {method 'startswith' of 'str' objects}
#       117    0.031    0.000    1.032    0.009 {function Pickler.dump at 0x7f8bde76da80}
#      1443    0.029    0.000    0.032    0.000 {built-in method _pickle.dumps}
#     15832    0.026    0.000    0.027    0.000 {built-in method builtins.len}
#      4290    0.026    0.000    0.883    0.000 cloudpickle.py:1348(reducer_override)
#     13416    0.024    0.000    0.024    0.000 {method 'split' of 'str' objects}
# ...

# %%
plot_word_unit_responses("l^k", word_values_agg, slice_num, input_string)
# Out:
# (39,)
#     Time Max Activation Word  Probability
# 5      5                 art     0.037316
# 2      2                 art     0.037222
# 1      1                 art     0.036383
# 4      4                 art     0.035746
# 0      0                 art     0.035685
# 3      3                 art     0.035084
# 20    20                trit     0.030896
# 8      8                 rut     0.029128
# 6      6                 rut     0.028941
# 19    19                trit     0.028796
# 7      7                 rut     0.028558
# 21    21                trit     0.027840
# 18    18                trit     0.027668
# 23    23                trit     0.027400
# 17    17               tr^st     0.027047
# 22    22                trit     0.026017
# 16    16               tr^st     0.025945
# 27    27           s^bst^tut     0.024309
# 15    15              targ^t     0.024267
# 24    24                 art     0.023343
# 11    11                 rut     0.022930
# ...

# %%
plot_probe_responses(probe_values, probes)
